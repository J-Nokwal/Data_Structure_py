# %%
import numpy as np
import pandas as pd
import nltk 
from nltk.tokenize import sent_tokenize,word_tokenize
import sklearn
from data1 import topics
from data2 import qes
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import re

# %%
clean_text_1=[words.lower() for words in topics]
clean_text_2=[sent_tokenize(sent) for sent in clean_text_1 ]

# %%
clean_text_3 =[]
for word in clean_text_2:
    clean=[]
    for w in word:
        res= re.sub(r'[^\w\s]',"",w)
        if res != "":
            clean.append(res)
    clean_text_3.append(clean)

# %%
clean_text_4=[]
for words in clean_text_3:
    w=[]
    for word in words:
        if not word in stopwords.words('english'):
            w.append(word)
    clean_text_4.append(w)

# %%
poter =PorterStemmer()
lem=[]
for words in clean_text_4:
    w=[]
    for word in words:
        w.append(poter.stem(word))
    lem.append(w)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
corpus=topics
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)

# %%
mat= pd.DataFrame(X.todense(),columns = vectorizer.get_feature_names_out().tolist())
mat
# Out:
#          10       100  10minimum        12       14        15       16  \
# 0  0.000000  0.000000   0.000000  0.000000  0.00000  0.151012  0.00000
# 1  0.014695  0.000000   0.000000  0.000000  0.00000  0.136468  0.00000
# 2  0.000000  0.023105   0.000000  0.000000  0.00000  0.000000  0.00000
# 3  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.00000
# 4  0.005419  0.010837   0.006608  0.284142  0.03304  0.022874  0.03304
# 5  0.000000  0.000000   0.000000  0.000000  0.00000  0.000000  0.00000
#
#          17        18      1970  ...   without     words      work     works  \
# 0  0.000000  0.000000  0.000000  ...  0.012584  0.000000  0.014906  0.000000
# 1  0.000000  0.000000  0.000000  ...  0.012406  0.012406  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.006696  ...  0.013907  0.009272  0.000000  0.006696
# 4  0.039648  0.019824  0.000000  ...  0.000000  0.013724  0.000000  0.000000
# ...

# %%
# !pip install matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(mat)
# Out:
# []
