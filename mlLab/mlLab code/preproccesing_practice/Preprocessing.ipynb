# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
titanic_train_pd=pd.read_csv("/home/rockbot/Documents/Data_Structure_py/mlLab/datasets/titanic/train_clean.csv")
titanic_train_pd
# Out:
#       Age Cabin Embarked     Fare  \
# 0    22.0   NaN        S   7.2500
# 1    38.0   C85        C  71.2833
# 2    26.0   NaN        S   7.9250
# 3    35.0  C123        S  53.1000
# 4    35.0   NaN        S   8.0500
# ..    ...   ...      ...      ...
# 886  27.0   NaN        S  13.0000
# 887  19.0   B42        S  30.0000
# 888  22.0   NaN        S  23.4500
# 889  26.0  C148        C  30.0000
# 890  32.0   NaN        Q   7.7500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
# ..                                                 ...    ...          ...
# ...

# %%
titanic_train_pd[titanic_train_pd["Cabin"].isnull()]
# (titanic_train_pd.iloc[0,1])
# Out:
#       Age Cabin Embarked     Fare                                      Name  \
# 0    22.0   NaN        S   7.2500                   Braund, Mr. Owen Harris
# 2    26.0   NaN        S   7.9250                    Heikkinen, Miss. Laina
# 4    35.0   NaN        S   8.0500                  Allen, Mr. William Henry
# 5    30.0   NaN        Q   8.4583                          Moran, Mr. James
# 7     2.0   NaN        S  21.0750            Palsson, Master. Gosta Leonard
# ..    ...   ...      ...      ...                                       ...
# 884  25.0   NaN        S   7.0500                    Sutehall, Mr. Henry Jr
# 885  39.0   NaN        Q  29.1250      Rice, Mrs. William (Margaret Norton)
# 886  27.0   NaN        S  13.0000                     Montvila, Rev. Juozas
# 888  22.0   NaN        S  23.4500  Johnston, Miss. Catherine Helen "Carrie"
# 890  32.0   NaN        Q   7.7500                       Dooley, Mr. Patrick
#
# ...
